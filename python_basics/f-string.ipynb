# %% [markdown]
# # f-string in Python
# **f-strings was introduced in Python 3.6<br>f-string are used for embedding variables inside the string**

# %%
name = 'Aashish Kr Ray'
age = 23

# %%
# Tradational Method
print("My name is " +  name + " & I am "  +str(age) + " years old")
# Out:
# My name is Aashish Kr Ray & I am 23 years old

# %%
#f-string method
print(f"My name is {name} & I am {age} years old")
# Out:
# My name is Aashish Kr Ray & I am 23 years old

# %% [markdown]
# # Expression using f-string

# %%
x = 21
y = 23
print(f"Sum : {x + y}")
# Out:
# Sum : 44

# %% [markdown]
# # Function using f-string

# %%
surname = "ray"
first_name = "AASHISH"
print(f"First_Name : {first_name.lower()}")
print(f"Surname : {surname.upper()}")
# Out:
# First_Name : aashish
# Surname : RAY

# %%
pi = 3.141596
print(f"pi : {pi:.2f}")
# Out:
# pi : 3.14

# %%
name = "Aashish"
print(f"|{name : <20}|") # < is used for left alignment
print(f"|{name : ^20}|") # ^ is used for center alignment
print(f"|{name : >20}|") # > is used for right alignment
# Out:
# |Aashish             |
# |      Aashish       |
# |             Aashish|
