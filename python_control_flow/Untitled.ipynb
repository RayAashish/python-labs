# %% [markdown]
# # Loop
# **Loop is used for repeating the code <br>There are only two types of loop in Python unlike 3 in java**
# 1. for loop : Primarly used when loop when range is known
# ```python
#     # Syntax
#     for i in range:
#         # loop body
# ```
# 3. while loop
